# %% [markdown]
# Installing and Importing Dependancies

# %%
# !pip install ipywidgets
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)

# %%
# !cd yolov5-master & pip install -r requirements.txt
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# Load Model

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)

# %% [markdown]
# Snippet To Train the Model From the image dataset(Do Not run the below snippet)

# %%
# !cd yolov5-master && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-10-30 Python-3.10.6 torch-1.13.0+cpu CPU
#
# ...

# %%
pip install -U ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\abeya\anaconda3\envs\sigenv\lib\site-packages)

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5-master/runs/train/exp4/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\abeya/.cache\torch\hub\master.zip
# YOLOv5  2023-12-2 Python-3.10.6 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
import uuid
import os
import time
import matplotlib.pyplot

# %%
import cv2
import torch


img_path = r"C:\Users\abeya\Downloads\Brand_Detection_knowesis\Srini_dip_project\data\images\nike20.jpg"
img = cv2.imread(img_path)

# %%
results = model(img)

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 750x538 1 Nike
# Speed: 7.8ms pre-process, 237.6ms inference, 2.0ms NMS per image at shape (1, 3, 640, 480)

# %%
from IPython.display import display, Image
import numpy as np
from PIL import Image as PILImage

# Assuming `results` is a variable containing the image data
image_data = np.squeeze(results.render())

# Create a PIL Image object from the NumPy array
pil_image = PILImage.fromarray(np.uint8(image_data))

# Save the PIL Image to a temporary file
temp_image_path = 'temp_image.png'  # You can choose a different file format if needed
pil_image.save(temp_image_path)

# Display the saved image
display(Image(filename=temp_image_path))
